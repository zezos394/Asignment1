# %%
import numpy as np
filePath = "data\\univariateData.dat"
file = open(filePath, 'r')
allData = np.loadtxt(file,delimiter=',')
X = np.matrix(allData[:,:- 1])
y = np.matrix((allData[:,- 1])).T
n,d = X.shape

# %%
from test_linreg_univariate import plotData1D
plotData1D (X,y)

# %%
import numpy as np
from test_linreg_univariate import plotRegLine1D
from linreg import LinearRegression
X = np.c_[np.ones((n,1)),X] 
lr_model = LinearRegression(alpha = 0.01, n_iter = 1500)
lr_model.fit(X,y)
plotRegLine1D (lr_model, X, y )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6968\3189495602.py in <module>
#       4 X = np.c_[np.ones((n,1)),X]
#       5 lr_model = LinearRegression(alpha = 0.01, n_iter = 1500)
# ----> 6 lr_model.fit(X,y)
#       7 plotRegLine1D (lr_model, X, y )
#
# e:\Visual Studio Code\Python\AI\CIS419-master\Assignment1\hw1_skeleton\linreg.py in fit(self, X, y)
#      73         n = len(y)
#      74         n,d = X.shape
# ---> 75         if self.theta.any()==None:
#      76             self.theta = np.matrix(np.zeros((d,1)))
#      77         self.theta = self.gradientDescent(X,y,self.theta)
#
# AttributeError: 'NoneType' object has no attribute 'all'

# %%
pip test_linreg_univariate.py
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "test_linregunivariate.py"
